# %%
# %load_ext nb_black

# %%
# Basics
import tensorflow as tf
import pandas as pd
import xarray as xr

# Helpful
from tqdm import tqdm

# Visualization
import matplotlib.pyplot as plt

# My Methods
from src.utils.CRPS import *  # CRPS metrics
from src.utils.data_split import *  # Splitting data into X and y
from src.utils.drn_make_X_array import *  # Import make train array functions (make_X_array)
from src.models.EMOS import *  # EMOS implementation
from src.models.DRN.DRN_model import *  # DRN implementation
from src.models.DRN.DRN_load_score import *  # Load DRN_scores
from src.models.DRN.DRN_load_model import *  # Load Models
from src.models.DRN.DRN_train import *
from src.models.EMOS_local.EMOS_local_load_score import *  # Load EMOS_local_scores
from src.models.EMOS_global.EMOS_global_load_score import *  # Load EMOS_global_scores
from src.models.EMOS_global.EMOS_global_load_model import *  # Load EMOS_global_models#
import data.raw.load_data_raw as ldr  # Load raw data
import data.processed.load_data_processed as ldp  # Load processed data normed
import data.processed.load_data_processed_denormed as ldpd  # Load processed data denormed
from src.models.CRPS_baseline.CRPS_load import *  # Load CRPS scores
# Out:
# 2023-06-18 19:20:31.933952: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/opt/anaconda3/lib/
# 2023-06-18 19:20:31.933972: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ### 1. Load CRPS scores

# %%
# Baseline Scores
CRPS_baseline_scores_test_ws10 = crps_load_lead_lat_lon("ws10")
CRPS_baseline_scores_val_ws10 = crps_load_lead_lat_lon_val("ws10")
CRPS_baseline_scores_train_ws10 = crps_load_lead_lat_lon_train("ws10")

# Just to test add t2m
CRPS_baseline_scores_test_t2m = crps_load_lead_lat_lon("t2m")
CRPS_baseline_scores_val_t2m = crps_load_lead_lat_lon_val("t2m")

# %% [markdown]
# ### 2. Comparison Val and Test scores

# %%
for i in range(31):
    print(f"Train scores: {CRPS_baseline_scores_train_ws10[i].mean()} in lead {i}")
    print(f"Val scores: {CRPS_baseline_scores_val_ws10[i].mean()} in lead {i}")
    print(f"Test scores: {CRPS_baseline_scores_test_ws10[i].mean()} in lead {i}")
    print(
        f"Difference Test - Val {CRPS_baseline_scores_val_ws10[i].mean() - CRPS_baseline_scores_test_ws10[i].mean()} in lead {i}"
    )
    print("")
# Out:
# Train scores: 0.6603173613548279 in lead 0
# Val scores: 0.6658014059066772 in lead 0
# Test scores: 0.4708288311958313 in lead 0
# Difference Test - Val 0.19497257471084595 in lead 0
#
# Train scores: 0.7574978470802307 in lead 1
# Val scores: 0.7732185125350952 in lead 1
# Test scores: 0.5626273155212402 in lead 1
# Difference Test - Val 0.21059119701385498 in lead 1
#
# Train scores: 0.8004212379455566 in lead 2
# Val scores: 0.8087474703788757 in lead 2
# Test scores: 0.5660684704780579 in lead 2
# Difference Test - Val 0.24267899990081787 in lead 2
#
# Train scores: 0.8202793002128601 in lead 3
# Val scores: 0.8332287073135376 in lead 3
# Test scores: 0.6244665384292603 in lead 3
# Difference Test - Val 0.20876216888427734 in lead 3
#
# Train scores: 0.839388370513916 in lead 4
# Val scores: 0.841774582862854 in lead 4
# Test scores: 0.6273626685142517 in lead 4
# Difference Test - Val 0.2144119143486023 in lead 4
#
# Train scores: 0.8983346819877625 in lead 5
# Val scores: 0.9103854894638062 in lead 5
# Test scores: 1.3470748662948608 in lead 22
# Difference Test - Val 0.12272810935974121 in lead 22
#
# Train scores: 1.473615050315857 in lead 23
# Val scores: 1.4587452411651611 in lead 23
# Test scores: 1.3625421524047852 in lead 23
# Difference Test - Val 0.09620308876037598 in lead 23
#
# Train scores: 1.50057053565979 in lead 24
# Val scores: 1.463258981704712 in lead 24
# Test scores: 1.370863676071167 in lead 24
# Difference Test - Val 0.09239530563354492 in lead 24
#
# Train scores: 1.5762989521026611 in lead 25
# Val scores: 1.5491501092910767 in lead 25
# Test scores: 1.476784110069275 in lead 25
# Difference Test - Val 0.07236599922180176 in lead 25
#
# Train scores: 1.5514005422592163 in lead 26
# Val scores: 1.5221705436706543 in lead 26
# Test scores: 1.4213701486587524 in lead 26
# Difference Test - Val 0.10080039501190186 in lead 26
#
# Train scores: 1.5290770530700684 in lead 27
# Val scores: 1.5038292407989502 in lead 27
# Test scores: 1.4293179512023926 in lead 27
# Difference Test - Val 0.07451128959655762 in lead 27
#
# Train scores: 1.5488909482955933 in lead 28
# Val scores: 1.5022987127304077 in lead 28
# Test scores: 1.4322772026062012 in lead 28
# Difference Test - Val 0.07002151012420654 in lead 28
#
# Train scores: 1.6176297664642334 in lead 29
# Val scores: 1.586258053779602 in lead 29
# Test scores: 1.536927580833435 in lead 29
# Difference Test - Val 0.04933047294616699 in lead 29
#
# Train scores: 1.5838844776153564 in lead 30
# Val scores: 1.547132968902588 in lead 30
# Test scores: 1.4698940515518188 in lead 30
# Difference Test - Val 0.07723891735076904 in lead 30

# %%
for i in range(31):
    print(f"Val scores: {CRPS_baseline_scores_val_t2m[i].mean()} in lead {i}")
    print(f"Test scores: {CRPS_baseline_scores_test_t2m[i].mean()} in lead {i}")
    print(
        f"Difference Test - Val {CRPS_baseline_scores_val_t2m[i].mean() - CRPS_baseline_scores_test_t2m[i].mean()} in lead {i}"
    )
    print("")
# Out:
# Val scores: 0.5012174149060862 in lead 0
# Test scores: 0.5084816639136492 in lead 0
# Difference Test - Val -0.007264249007563062 in lead 0
#
# Val scores: 0.5049655545333702 in lead 1
# Test scores: 0.5347707002046389 in lead 1
# Difference Test - Val -0.029805145671268685 in lead 1
#
# Val scores: 0.49082135951235406 in lead 2
# Test scores: 0.5150757989800734 in lead 2
# Difference Test - Val -0.024254439467719324 in lead 2
#
# Val scores: 0.5218363688739838 in lead 3
# Test scores: 0.5301602687833538 in lead 3
# Difference Test - Val -0.008323899909369992 in lead 3
#
# Val scores: 0.5450302728645224 in lead 4
# Test scores: 0.5624034501418446 in lead 4
# Difference Test - Val -0.017373177277322127 in lead 4
#
# Val scores: 0.5928348029515252 in lead 5
# Test scores: 0.6306282599852645 in lead 5
# Difference Test - Val -0.037793457033739264 in lead 5
#
# Val scores: 0.5948379144402783 in lead 6
# Test scores: 0.6316119778923832 in lead 6
# Difference Test - Val -0.03677406345210488 in lead 6
#
# Val scores: 0.6225855392322349 in lead 7
# Test scores: 0.6454345388357919 in lead 7
# Difference Test - Val -0.02284899960355702 in lead 7
#
# Val scores: 0.6441880750204837 in lead 8
# Test scores: 0.6802850949781106 in lead 8
# Difference Test - Val -0.03609701995762693 in lead 8
#
# Val scores: 0.6949128641658414 in lead 9
# Test scores: 0.7561511514525252 in lead 9
# Difference Test - Val -0.06123828728668379 in lead 9
#
# Val scores: 0.6968741665368038 in lead 10
# Test scores: 0.7596827249402444 in lead 10
# Difference Test - Val -0.06280855840344057 in lead 10
#
# Val scores: 0.7254956811791945 in lead 11
# Test scores: 0.7671595364524374 in lead 11
# Difference Test - Val -0.0416638552732429 in lead 11
#
# Val scores: 0.7561492205151459 in lead 12
# Test scores: 0.8087436349681829 in lead 12
# Difference Test - Val -0.05259441445303703 in lead 12
#
# Val scores: 0.8119890656955935 in lead 13
# Test scores: 0.8907210185014609 in lead 13
# Difference Test - Val -0.07873195280586742 in lead 13
#
# Val scores: 0.8100356644764907 in lead 14
# Test scores: 0.8895929183430251 in lead 14
# Difference Test - Val -0.07955725386653445 in lead 14
#
# Val scores: 0.8350695384225983 in lead 15
# Test scores: 0.8913402208770865 in lead 15
# Difference Test - Val -0.056270682454488186 in lead 15
#
# Val scores: 0.8701804107979364 in lead 16
# Test scores: 0.9354666921537256 in lead 16
# Difference Test - Val -0.06528628135578918 in lead 16
#
# Val scores: 0.9271078216065111 in lead 17
# Test scores: 1.030760697007392 in lead 17
# Difference Test - Val -0.10365287540088086 in lead 17
#
# Val scores: 0.9216690128021141 in lead 18
# Test scores: 1.020928305756169 in lead 18
# Difference Test - Val -0.099259292954055 in lead 18
#
# Val scores: 0.947744717917542 in lead 19
# Test scores: 1.011146119667486 in lead 19
# Difference Test - Val -0.06340140174994402 in lead 19
#
# Val scores: 0.9880487623222679 in lead 20
# Test scores: 1.0559743772319934 in lead 20
# Difference Test - Val -0.06792561490972548 in lead 20
#
# Val scores: 1.0461986488667796 in lead 21
# Test scores: 1.170507971000092 in lead 21
# Difference Test - Val -0.12430932213331247 in lead 21
#
# Val scores: 1.032023459070752 in lead 22
# Test scores: 1.1471350159491147 in lead 22
# Difference Test - Val -0.11511155687836272 in lead 22
#
# Val scores: 1.0481665648678884 in lead 23
# Test scores: 1.1231032795400633 in lead 23
# Difference Test - Val -0.07493671467217489 in lead 23
#
# Val scores: 1.09230976619894 in lead 24
# Test scores: 1.1665183732402151 in lead 24
# Difference Test - Val -0.07420860704127508 in lead 24
#
# Val scores: 1.1598661089655038 in lead 25
# Test scores: 1.291409822220935 in lead 25
# Difference Test - Val -0.13154371325543113 in lead 25
#
# Val scores: 1.138746143432951 in lead 26
# Test scores: 1.2553212202206236 in lead 26
# Difference Test - Val -0.11657507678767254 in lead 26
#
# Val scores: 1.1360605763483544 in lead 27
# Test scores: 1.2185923742165932 in lead 27
# Difference Test - Val -0.08253179786823872 in lead 27
#
# Val scores: 1.17774105718864 in lead 28
# Test scores: 1.261623224976432 in lead 28
# Difference Test - Val -0.08388216778779212 in lead 28
#
# Val scores: 1.2479079068236625 in lead 29
# Test scores: 1.4120354238676378 in lead 29
# Difference Test - Val -0.16412751704397532 in lead 29
#
# Val scores: 1.2198274535447458 in lead 30
# Test scores: 1.3563336012079834 in lead 30
# Difference Test - Val -0.13650614766323765 in lead 30
